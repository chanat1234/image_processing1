# %% [markdown]
# <a href="https://colab.research.google.com/github/chanat1234/image_processing1/blob/main/Copy_of_Colab_Vision_Ex1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Initialization

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
import cv2
import os

from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# Show OpenCV's version

print(cv2.__version__)
# Out:
# 4.7.0

# %% [markdown]
# ##Read and write image

# %%
image_path = "/content/gdrive/My Drive/AI_Course/images"
img = cv2.imread(os.path.join(image_path,'image1.jpg'),cv2.IMREAD_COLOR)

# %%
cv2.imwrite(os.path.join(image_path,'output.jpg'), img)
# Out:
# True

# %% [markdown]
# **Check type of img**

# %%
print(type(img))

print(img.shape)

print(img.size)

print(img.dtype)
# Out:
# <class 'numpy.ndarray'>
# (363, 600, 3)
# 653400
# uint8

# %% [markdown]
# ## Display image

# %%
plt.imshow(img)
plt.show()

# %% [markdown]
# Notes: Different order of color channels
# - cv2: BGR
# - plt: RGB

# %%
imgrgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.imshow(imgrgb)
plt.show()

# Or, use fun numpy functions / indexing!
imgrgb = img[:,:,::-1]
plt.imshow(imgrgb)
plt.show()

# %% [markdown]
# **For GRAYSCALE Image**

# %%
img_gray = cv2.imread(os.path.join(image_path,'image1.jpg'),cv2.IMREAD_GRAYSCALE)

# %%
plt.axis("off")
plt.imshow(img_gray,'gray')
plt.show()

print(type(img_gray))
print('Shape:', img_gray.shape)
print('Size:', img_gray.size)
print('Data type:', img_gray.dtype)
# Out:
# <class 'numpy.ndarray'>
# Shape: (363, 600)
# Size: 217800
# Data type: uint8

# %% [markdown]
# ##Accessing pixels (Numpy Basic)

# %%
# Get value of a specific pixel
px = imgrgb[100,100]

print(px)

# Change pixel value
imgrgb[55,55] = [255,255,255]

# %%
# Show specific region of the image
plt.axis("off")
plt.imshow(imgrgb[0:200,250:500,:])
plt.show()

# %% [markdown]
# ##Basic Operations on Images

# %%
# Resize to specific size
res = cv2.resize(imgrgb, (150,100))
plt.imshow(res)
plt.show()

# Expanding by scaling
res = cv2.resize(imgrgb, None,fx=2, fy=2, interpolation = cv2.INTER_CUBIC)
plt.imshow(res)
plt.show()

# Shrinking by scaling
res = cv2.resize(imgrgb, None,fx=.1, fy=.1, interpolation = cv2.INTER_CUBIC)
plt.imshow(res)
plt.show()

# %%
img_flip_x = cv2.flip(imgrgb, 0)  # flip along its horizontal x-axis
plt.axis("off")
plt.imshow(img_flip_x)
plt.show()

img_flip_y = cv2.flip(imgrgb, 1)  # flip along its vertical y-axis
plt.axis("off")
plt.imshow(img_flip_y)
plt.show()

img_flip = cv2.flip(imgrgb, -1)   # how about this one?
plt.axis("off")
plt.imshow(img_flip)
plt.show()

# %% [markdown]
# ##Converting Color Space

# %%
img = cv2.imread(os.path.join(image_path,'color_wheel.jpg'),cv2.IMREAD_COLOR)
print('Shape:', img.shape)

# Convert BGR to RGB
imgrgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.axis("off")
plt.imshow(imgrgb)
plt.show()

# Convert BGR to grayscale
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.axis("off")
plt.imshow(img_gray,'gray')
plt.show()

# Convert BGR to HSV
img_hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
plt.axis("off")
plt.imshow(img_hsv)
plt.show()

# Display H channel
plt.axis("off")
plt.imshow(img_hsv[:,:,0])
plt.show()

# Display S channel
plt.axis("off")
plt.imshow(img_hsv[:,:,1])
plt.show()

# Display V channel
plt.axis("off")
plt.imshow(img_hsv[:,:,2])
plt.show()
